# %%
import numpy as np
from scipy.stats import binom
binom.pmf(p=0.5,k=2,n=5)
# Out:
# np.float64(0.31249999999999983)

# %%
np.float64
# Out:
# numpy.float64

# %%
binom.pmf(p=0.5,k=1,n=5)
# Out:
# np.float64(0.15624999999999997)

# %%
np.float64
# Out:
# numpy.float64

# %%
binom.cdf(p=0.5,k=2,n=5)
# Out:
# np.float64(0.5)

# %%
np.float64
# Out:
# numpy.float64

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
x=random.binomial(n=10,p=0.5,size=1000)
sns.histplot(x,kde=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
mu, sigma = 0.5, 0.1
s= np.random.normal(mu, sigma, 1000) #create the bins and histogram
n,bins, p= plt.hist(s, 20, density=True) #plot the distribution curve
plt.plot(bins,1/(sigma * np.sqrt(2 * np.pi)) * np.exp( -(bins - mu)**2 / (2 *  sigma**2) ), linewidth=3, color='y')
plt.show()

# %%
#poisson
from scipy.stats import poisson
mu=3
k=5
poisson.pmf(mu,k)
# Out:
# np.float64(0.1403738958142805)

# %%
np.float64
# Out:
# numpy.float64

# %%
poisson.rvs(mu=5,size=100)
# Out:
# array([ 8,  6,  7,  3,  6,  6,  4,  3,  5,  4,  9,  5,  5,  8,  6,  8,  8,
#         5,  7,  4,  3,  5,  4,  7,  4,  4,  3,  2,  3,  1,  9,  7,  3,  2,
#         4,  8,  6, 11,  5,  6,  4,  6,  7,  1,  4,  2,  4,  6,  5,  3,  4,
#         3,  1,  4,  4,  3,  7,  4, 11,  3,  6,  3,  8,  6,  3,  0,  6,  7,
#         6,  6,  7,  4,  7,  6,  3,  4,  7,  4,  7,  5,  7,  9,  5,  5,  6,
#         2,  3,  5,  1,  6,  4,  9,  2,  7,  6,  9,  5,  8,  7,  2])

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
#generate Poisson distribution with sample size 10000
x=poisson.rvs(mu=3,size=10000)
#create plot of Poisson distribution
plt.hist(x,density=True,edgecolor='black')
plt.show()

# %%
import numpy as np
import scipy.stats as stats
data=np.array([6,7,7,12,4,5,4,3,556,7,8,])
data=stats.zscore(data)
print(data)
data=data.reshape(-1,1)
print(data)
# Out:
# [-0.31809137 -0.31176406 -0.31176406 -0.28012748 -0.330746   -0.32441869
#  -0.330746   -0.33707332  3.16193179 -0.31176406 -0.30543674]
# [[-0.31809137]
#  [-0.31176406]
#  [-0.31176406]
#  [-0.28012748]
#  [-0.330746  ]
#  [-0.32441869]
#  [-0.330746  ]
#  [-0.33707332]
#  [ 3.16193179]
#  [-0.31176406]
#  [-0.30543674]]

# %%
data.mean()
# Out:
# np.float64(1.5139404881252134e-17)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
data_scaled=sc.fit_transform(data)
data_scaled
# Out:
# array([[-0.31809137],
#        [-0.31176406],
#        [-0.31176406],
#        [-0.28012748],
#        [-0.330746  ],
#        [-0.32441869],
#        [-0.330746  ],
#        [-0.33707332],
#        [ 3.16193179],
#        [-0.31176406],
#        [-0.30543674]])

# %%
sa=np.array([[-0.40039619],
       [-0.38829631],
       [-0.38829631],
       [-0.32779688],
       [-0.315697  ],
       [-0.315697  ],
       [-0.29149723],
       [-0.27939734],
       [-0.24309769],
       [-0.20679803],
       [ 3.15696998]])
sa
# Out:
# array([[-0.40039619],
#        [-0.38829631],
#        [-0.38829631],
#        [-0.32779688],
#        [-0.315697  ],
#        [-0.315697  ],
#        [-0.29149723],
#        [-0.27939734],
#        [-0.24309769],
#        [-0.20679803],
#        [ 3.15696998]])

# %%
sa.mean()
# Out:
# np.float64(4.0371746350005693e-17)

# %%
np.float64
# Out:
# numpy.float64

# %%
sa.std()
# Out:
# np.float64(1.0000000008752112)

# %%
import numpy as np
import scipy.stats as st
population =np.array( [12, 12, 13, 13, 15, 16, 17, 22, 23, 25, 26, 27, 28, 28, 29])
sample=np.array([12,13,17,25,28])
st.t.interval(confidence=0.95, df=len(sample)-1, loc=np.mean(sample),  scale=st.sem(sample))
# Out:
# (np.float64(10.089384507879313), np.float64(27.910615492120687))

# %%
population =np.array( [12, 12, 13, 13, 15, 16, 17, 22, 23, 25, 26, 27, 28, 28, 29])
population.mean()
# Out:
# np.float64(20.4)

# %%
np.float64()
# Out:
# np.float64(0.0)

# %%
sample.mean()
# Out:
# np.float64(19.0)

# %%
np.float64(19.0)
# Out:
# np.float64(19.0)
