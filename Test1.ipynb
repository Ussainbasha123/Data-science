# %%
import numpy as np

# %%
import pandas as pd

# %%
from scipy import stats

# %%
a=np.array([1,2,3])
print(a[0])
print(a[2])
# Out:
# 1
# 3

# %%
b=np.array([[1,2,3],[4,5,6]])
np.ndim(b)
print(b[1][2])
print(b[0])
# Out:
# 6
# [1 2 3]

# %%
c=np.arange(1,10)
c[2:7]
# Out:
# array([3, 4, 5, 6, 7])

# %%
#4.replace
d=np.array([1,-1,2,-2,3,-3])
d[d<0]=0
d
# Out:
# array([1, 0, 2, 0, 3, 0])

# %%
#5.
print(a)
print(b)
a+b
# Out:
# [1 2 3]
# [[1 2 3]
#  [4 5 6]]
# array([[2, 4, 6],
#        [5, 7, 9]])

# %%
#6.unique and value_counts
aa=np.array([1,2,2,3,3,3,4])
aa=np.unique(aa,return_counts=True)
aa
# Out:
# (array([1, 2, 3, 4]), array([1, 2, 3, 1]))

# %%
#7.replace even with zero
a1=np.array([1,2,3,4,5,6,7,8])
a1[a1%2==0]=0
a1
# Out:
# array([1, 0, 3, 0, 5, 0, 7, 0])

# %%
#8.multiply using array loop and vectorization
a2=np.array([1,2,3,4])
#loop
result=np.array([x*2 for x in a2])
print(result)
#vectorization
result1=a2*2
print(result1)
# Out:
# [2 4 6 8]
# [2 4 6 8]

# %%
pip install matp

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
d=sns.load_dataset('tips')

# %%
d
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
c=["Bmw","M,series","M4"]
s=[900,387,250]
plt.bar(c,s,color=["blue","black","lightblue"])
plt.title("Cars")
plt.xlabel("Best Brands")
plt.ylabel("no of models")
plt.show()

# %%
plt.plot(c,s)
plt.title("Bmw")
plt.xlabel("Best Model m4")
plt.ylabel("Model No:m4")
plt.show()

# %%
plt.pie([30,40,30],labels=['a','b','c'],autopct='%1.1f%%')
plt.show()
