# %%
import re

# %%
text="this is my id 9025"
n=re.findall(r"\d",text)
n
# Out:
# ['9', '0', '2', '5']

# %%
t="machine learning i like machine learning i like machine learning"
m=re.search("machine learning",t)
m
# Out:
# <re.Match object; span=(0, 16), match='machine learning'>

# %%
t="machine learning"
match=re.match("machine learning",t)

print(match)
# Out:
# <re.Match object; span=(0, 16), match='machine learning'>

# %%
a="#$%^&* ^$& yffg jhfuyfyh &&&*"
n=re.sub("&","!",a)
n
# Out:
# '#$%^!* ^$! yffg jhfuyfyh !!!*'
